# %% [markdown]
# <a href="https://colab.research.google.com/github/GuidoJr84/projeto-dados-science/blob/main/AluraStoreBrasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
loja.to_csv('loja.csv', index=False)

# %% [markdown]
# #1. Análise do faturamento

# %%
loja = loja.dropna()
display(loja.info())
display(loja.describe().round(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None
# ...

# %%
loja2 = loja2.dropna()
display(loja2.info())
display(loja2.describe().round(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None
# ...

# %%
loja3 = loja3.dropna()
display(loja3.info())
display(loja3.describe().round(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None
# ...

# %%
loja4 = loja4.dropna()
display(loja4.info())
display(loja4.describe().round(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2358 non-null   object
#  1   Categoria do Produto    2358 non-null   object
#  2   Preço                   2358 non-null   float64
#  3   Frete                   2358 non-null   float64
#  4   Data da Compra          2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Local da compra         2358 non-null   object
#  7   Avaliação da compra     2358 non-null   int64
#  8   Tipo de pagamento       2358 non-null   object
#  9   Quantidade de parcelas  2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB
# None
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
faturamento_total = loja['Preço'].sum()

print("Faturamento total da loja:", faturamento_total)
# Out:
# Faturamento total da loja: 1534509.12

# %%
faturamento_formatado = f"R$ {faturamento_total:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

print("Faturamento total da loja:", faturamento_formatado)
# Out:
# Faturamento total da loja: R$ 1.534.509,12

# %%
ranking_categorias = loja.groupby('Categoria do Produto')['Preço'].sum()
ranking_categorias = ranking_categorias.sort_values(ascending=False)
print(ranking_categorias)
# Out:
# Categoria do Produto
# eletronicos              572659.23
# eletrodomesticos         484913.36
# moveis                   250178.11
# instrumentos musicais    121731.69
# esporte e lazer           52387.55
# brinquedos                23993.78
# utilidades domesticas     16931.48
# livros                    11713.92
# Name: Preço, dtype: float64

# %%
ranking_categorias = loja.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)
ranking_formatado = ranking_categorias.apply(lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Ranking de categorias (da mais vendida à menos vendida):")
print(ranking_formatado)
# Out:
# Ranking de categorias (da mais vendida à menos vendida):
# Categoria do Produto
# eletronicos              R$ 572.659,23
# eletrodomesticos         R$ 484.913,36
# moveis                   R$ 250.178,11
# instrumentos musicais    R$ 121.731,69
# esporte e lazer           R$ 52.387,55
# brinquedos                R$ 23.993,78
# utilidades domesticas     R$ 16.931,48
# livros                    R$ 11.713,92
# Name: Preço, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Agrupar por categoria e somar o total de vendas
ranking_categorias = loja.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)

# Criar o gráfico de barras
plt.figure(figsize=(9, 5))
barras = plt.bar(ranking_categorias.index, ranking_categorias.values, color='#4B9CD3', edgecolor='black')

# Título e rótulos
plt.title('🏆 Faturamento por Categoria de Produto', fontsize=14, fontweight='bold')
plt.xlabel('Categoria', fontsize=11)
plt.ylabel('Faturamento (R$)', fontsize=11)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adicionar os valores em reais acima das barras
for barra in barras:
    valor = barra.get_height()
    texto = f"R$ {valor:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    plt.text(barra.get_x() + barra.get_width() / 2, valor + (valor * 0.01), texto,
             ha='center', va='bottom', fontsize=9, fontweight='bold', color='#333333')

# Ajustar o layout
plt.tight_layout()
plt.show()
from google.colab import files
plt.savefig('🏆 Faturamento por Categoria de Produto.png', dpi=300, bbox_inches='tight')

# Exibir o gráfico no Colab
plt.show()
files.download('🏆 Faturamento por Categoria de Produto.png')
plt.savefig('🏆 Faturamento por Categoria de Produto', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-3372381481.py:26: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.savefig('🏆 Faturamento por Categoria de Produto.png', dpi=300, bbox_inches='tight')

# Exibir o gráfico no Colab
plt.show()

# %%
from google.colab import files
plt.savefig('🏆 Faturamento por Categoria de Produto.png', dpi=300, bbox_inches='tight')

# Exibir o gráfico no Colab
plt.show()
files.download('🏆 Faturamento por Categoria de Produto.png')
plt.savefig('🏆 Faturamento por Categoria de Produto', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd

# Agrupar por produto e somar o valor total de vendas
ranking_produtos = loja.groupby('Produto')['Preço'].sum().sort_values(ascending=False)

# Formatar os valores em reais
ranking_produtos_formatado = ranking_produtos.apply(
    lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
)

# Exibir o ranking formatado
print("🏆 Ranking dos produtos mais vendidos (em valor de R$):")
print(ranking_produtos_formatado.head(20))  # Mostra os 20 primeiros
# Out:
# 🏆 Ranking dos produtos mais vendidos (em valor de R$):
# Produto
# TV Led UHD 4K            R$ 189.534,28
# Geladeira                R$ 149.524,28
# Celular Plus X42         R$ 130.536,40
# Smart TV                  R$ 89.936,15
# Lavadora de roupas        R$ 87.711,30
# Lava louças               R$ 82.739,86
# Secadora de roupas        R$ 78.749,73
# Tablet ABXY               R$ 63.520,11
# Bateria                   R$ 50.258,34
# Guitarra                  R$ 49.722,88
# Micro-ondas               R$ 46.348,89
# Celular ABXY              R$ 43.534,47
# Sofá retrátil             R$ 41.839,25
# Cama king                 R$ 41.569,04
# Fogão                     R$ 39.839,30
# Guarda roupas             R$ 39.282,78
# Bicicleta                 R$ 36.592,38
# Cama box                  R$ 29.459,35
# Cadeira de escritório     R$ 23.556,36
# Impressora                R$ 21.884,23
# Name: Preço, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Agrupar por produto e somar vendas
ranking_produtos = loja.groupby('Produto')['Preço'].sum().sort_values(ascending=False)

# Número de produtos principais que você quer destacar
top_n = 10

# Separar top N produtos e agrupar o restante em 'Outros'
top_produtos = ranking_produtos[:top_n]
outros_valor = ranking_produtos[top_n:].sum()

# Criar nova série incluindo 'Outros'
valores_pizza = pd.concat([top_produtos, pd.Series({'Outros': outros_valor})])


# Cores
cores = plt.cm.tab20.colors

# Explodir a fatia do produto que mais faturou
explode = [0.1] + [0]*(len(valores_pizza)-1)

# Criar gráfico de pizza
plt.figure(figsize=(9,9))
plt.pie(
    valores_pizza,
    labels=valores_pizza.index,
    autopct=lambda p: f"R$ {p * valores_pizza.sum() / 100:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."),
    colors=cores,
    startangle=90,
    wedgeprops={'edgecolor':'black'},
    explode=explode,
    shadow=True
)

plt.title(f'🏆 Top {top_n} Produtos Mais Vendidos + Outros (R$)', fontsize=14, fontweight='bold')
plt.axis('equal')  # Mantém a pizza redonda

# Salvar o gráfico
nome_arquivo = 'pizza_produtos_outros.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# Exibir gráfico
plt.show()

# Baixar gráfico
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-1634435824.py:43: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- Estatísticas básicas ---
media_avaliacao = loja['Avaliação da compra'].mean()
mediana_avaliacao = loja['Avaliação da compra'].median()
moda_avaliacao = loja['Avaliação da compra'].mode()[0]

print(f"Média das avaliações: {media_avaliacao:.2f}")
print(f"Mediana das avaliações: {mediana_avaliacao}")
print(f"Moda das avaliações: {moda_avaliacao}")

# --- Contagem de cada nota ---
contagem_notas = loja['Avaliação da compra'].value_counts().sort_index()

# --- Exibir gráfico de barras ---
plt.figure(figsize=(8,5))
plt.bar(contagem_notas.index, contagem_notas.values, color='royalblue', edgecolor='black')
plt.title('Distribuição das Avaliações dos Clientes', fontsize=14, fontweight='bold')
plt.xlabel('Nota de Avaliação')
plt.ylabel('Quantidade de Clientes')
plt.xticks([1,2,3,4,5])
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# --- Percentual de avaliações positivas (>=4) ---
positivas = (loja['Avaliação da compra'] >= 4).sum()
total = loja['Avaliação da compra'].count()
percentual_positivas = (positivas / total) * 100

print(f"\n📈 Avaliações positivas (4 e 5): {percentual_positivas:.2f}% do total")
# Out:
# Média das avaliações: 3.98
# Mediana das avaliações: 5.0
# Moda das avaliações: 5
# 📈 Avaliações positivas (4 e 5): 73.59% do total

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files  # Para baixar o arquivo no Colab

# --- Filtrar avaliações positivas (nota >= 4) ---
avaliacoes_positivas = loja[loja['Avaliação da compra'] >= 4]

# --- Agrupar por produto: média e quantidade de avaliações ---
resumo_produtos = avaliacoes_positivas.groupby('Produto')['Avaliação da compra'].agg(['mean','count'])

# --- Selecionar TOP 5 produtos por média de avaliação ---
top5_produtos = resumo_produtos.sort_values('mean', ascending=False).head(5)

# --- Gráfico de bolhas ---
plt.figure(figsize=(10,6))
plt.scatter(
    x=top5_produtos.index,             # nomes dos produtos
    y=top5_produtos['mean'],           # média das avaliações
    s=top5_produtos['mean']*300,       # tamanho das bolhas proporcional à média
    color='mediumseagreen',
    alpha=0.7,
    edgecolors='black'
)

# Adicionar valores das médias acima das bolhas
for i, valor in enumerate(top5_produtos['mean']):
    plt.text(i, valor + 0.05, f"{valor:.2f}", ha='center', fontsize=10, fontweight='bold')

plt.title('🌟 TOP 5 Produtos Mais Bem Avaliados (nota ≥4)', fontsize=14, fontweight='bold')
plt.xlabel('Produto', fontsize=12)
plt.ylabel('Média das Avaliações', fontsize=12)
plt.ylim(4,5.2)  # Limite do eixo y para destacar notas altas
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# --- Salvar gráfico em .png ---
nome_arquivo = 'top5_produtos_bem_avaliados.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# --- Exibir gráfico ---
plt.show()

# --- Baixar gráfico automaticamente ---
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-1267025554.py:34: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1267025554.py:38: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
media_frete_loja1 = loja['Frete'].mean()
media_frete_loja2 = loja2['Frete'].mean()
media_frete_loja3 = loja3['Frete'].mean()
media_frete_loja4 = loja4['Frete'].mean()

print(f"Média do valor do frete da Loja 1: R$ {media_frete_loja1:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print(f"Média do valor do frete da Loja 2: R$ {media_frete_loja2:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print(f"Média do valor do frete da Loja 3: R$ {media_frete_loja3:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print(f"Média do valor do frete da Loja 4: R$ {media_frete_loja4:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
# Out:
# Média do valor do frete da Loja 1: R$ 34,69
# Média do valor do frete da Loja 2: R$ 33,62
# Média do valor do frete da Loja 3: R$ 33,07
# Média do valor do frete da Loja 4: R$ 31,28

# %%
faturamento_total = loja2['Preço'].sum()

print("Faturamento total da loja2:", faturamento_total)
# Out:
# Faturamento total da loja2: 1488459.06

# %%
faturamento_formatado = f"R$ {faturamento_total:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

print("Faturamento total da loja2:", faturamento_formatado)
# Out:
# Faturamento total da loja2: R$ 1.488.459,06

# %%
faturamento_total = loja3['Preço'].sum()

print("Faturamento total da loja3:", faturamento_total)
# Out:
# Faturamento total da loja3: 1464025.03

# %%
faturamento_formatado = f"R$ {faturamento_total:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

print("Faturamento total da loja3:", faturamento_formatado)
# Out:
# Faturamento total da loja3: R$ 1.464.025,03

# %%
faturamento_total = loja4['Preço'].sum()

print("Faturamento total da loja4:", faturamento_total)
# Out:
# Faturamento total da loja4: 1384497.58

# %%
faturamento_formatado = f"R$ {faturamento_total:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

print("Faturamento total da loja4:", faturamento_formatado)
# Out:
# Faturamento total da loja4: R$ 1.384.497,58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
ranking_categorias = loja2.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)
ranking_formatado = ranking_categorias.apply(lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Ranking de categorias (da mais vendida à menos vendida):")
print(ranking_formatado)
# Out:
# Ranking de categorias (da mais vendida à menos vendida):
# Categoria do Produto
# eletronicos              R$ 547.773,71
# eletrodomesticos         R$ 464.758,13
# moveis                   R$ 235.234,68
# instrumentos musicais    R$ 139.987,03
# esporte e lazer           R$ 46.326,09
# brinquedos                R$ 21.262,21
# utilidades domesticas     R$ 19.662,86
# livros                    R$ 13.454,35
# Name: Preço, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Agrupar por categoria e somar o total de vendas
ranking_categorias = loja2.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)

# Criar o gráfico de barras
plt.figure(figsize=(9, 5))
barras = plt.bar(ranking_categorias.index, ranking_categorias.values, color='#4B9CD3', edgecolor='black')

# Título e rótulos
plt.title('🏆 Faturamento por Categoria de Produto', fontsize=14, fontweight='bold')
plt.xlabel('Categoria', fontsize=11)
plt.ylabel('Faturamento (R$)', fontsize=11)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adicionar os valores em reais acima das barras
for barra in barras:
    valor = barra.get_height()
    texto = f"R$ {valor:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    plt.text(barra.get_x() + barra.get_width() / 2, valor + (valor * 0.01), texto,
             ha='center', va='bottom', fontsize=9, fontweight='bold', color='#333333')

# Ajustar o layout
plt.tight_layout()
plt.show()
from google.colab import files
plt.savefig('🏆 Faturamento por Categoria de Produto.png', dpi=300, bbox_inches='tight')

# Exibir o gráfico no Colab
plt.show()
files.download('🏆 Faturamento por Categoria de Produto.png')
plt.savefig('🏆 Faturamento por Categoria de Produto', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-4039910282.py:26: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd

# Agrupar por produto e somar o valor total de vendas
ranking_produtos = loja3.groupby('Produto')['Preço'].sum().sort_values(ascending=False)

# Formatar os valores em reais
ranking_produtos_formatado = ranking_produtos.apply(
    lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
)

# Exibir o ranking formatado
print("🏆 Ranking dos produtos mais vendidos (em valor de R$):")
print(ranking_produtos_formatado.head(20))  # Mostra os 20 primeiros
# Out:
# 🏆 Ranking dos produtos mais vendidos (em valor de R$):
# Produto
# Geladeira                R$ 133.185,99
# TV Led UHD 4K            R$ 128.892,11
# Celular Plus X42         R$ 124.300,84
# Smart TV                 R$ 105.116,46
# Lava louças               R$ 85.819,73
# Tablet ABXY               R$ 77.919,93
# Lavadora de roupas        R$ 76.612,58
# Secadora de roupas        R$ 66.397,97
# Celular ABXY              R$ 57.893,04
# Cama king                 R$ 51.779,90
# Fogão                     R$ 51.430,37
# Sofá retrátil             R$ 40.426,24
# Guitarra                  R$ 39.797,29
# Bateria                   R$ 39.158,71
# Cama box                  R$ 32.933,14
# Bicicleta                 R$ 32.872,35
# Guarda roupas             R$ 32.249,71
# Micro-ondas               R$ 25.538,25
# Cadeira de escritório     R$ 24.501,63
# Kit banquetas             R$ 22.265,96
# Name: Preço, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Agrupar por produto e somar vendas
ranking_produtos = loja2.groupby('Produto')['Preço'].sum().sort_values(ascending=False)

# Número de produtos principais que você quer destacar
top_n = 10

# Separar top N produtos e agrupar o restante em 'Outros'
top_produtos = ranking_produtos[:top_n]
outros_valor = ranking_produtos[top_n:].sum()

# Criar nova série incluindo 'Outros'
valores_pizza = pd.concat([top_produtos, pd.Series({'Outros': outros_valor})])


# Cores
cores = plt.cm.tab20.colors

# Explodir a fatia do produto que mais faturou
explode = [0.1] + [0]*(len(valores_pizza)-1)

# Criar gráfico de pizza
plt.figure(figsize=(9,9))
plt.pie(
    valores_pizza,
    labels=valores_pizza.index,
    autopct=lambda p: f"R$ {p * valores_pizza.sum() / 100:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."),
    colors=cores,
    startangle=90,
    wedgeprops={'edgecolor':'black'},
    explode=explode,
    shadow=True
)

plt.title(f'🏆 Top {top_n} Produtos Mais Vendidos + Outros (R$)', fontsize=14, fontweight='bold')
plt.axis('equal')  # Mantém a pizza redonda

# Salvar o gráfico
nome_arquivo = 'pizza_produtos_outros.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# Exibir gráfico
plt.show()

# Baixar gráfico
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-161315239.py:43: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ranking_categorias = loja3.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)
ranking_formatado = ranking_categorias.apply(lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Ranking de categorias (da mais vendida à menos vendida):")
print(ranking_formatado)
# Out:
# Ranking de categorias (da mais vendida à menos vendida):
# Categoria do Produto
# eletronicos              R$ 547.699,92
# eletrodomesticos         R$ 438.984,89
# moveis                   R$ 268.095,56
# instrumentos musicais    R$ 103.174,45
# esporte e lazer           R$ 47.456,10
# brinquedos                R$ 25.869,20
# utilidades domesticas     R$ 20.080,21
# livros                    R$ 12.664,70
# Name: Preço, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Agrupar por categoria e somar o total de vendas
ranking_categorias = loja3.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)

# Criar o gráfico de barras
plt.figure(figsize=(9, 5))
barras = plt.bar(ranking_categorias.index, ranking_categorias.values, color='#4B9CD3', edgecolor='black')

# Título e rótulos
plt.title('🏆 Faturamento por Categoria de Produto', fontsize=14, fontweight='bold')
plt.xlabel('Categoria', fontsize=11)
plt.ylabel('Faturamento (R$)', fontsize=11)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adicionar os valores em reais acima das barras
for barra in barras:
    valor = barra.get_height()
    texto = f"R$ {valor:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    plt.text(barra.get_x() + barra.get_width() / 2, valor + (valor * 0.01), texto,
             ha='center', va='bottom', fontsize=9, fontweight='bold', color='#333333')

# Ajustar o layout
plt.tight_layout()
plt.show()
from google.colab import files
plt.savefig('🏆 Faturamento por Categoria de Produto.png', dpi=300, bbox_inches='tight')

# Exibir o gráfico no Colab
plt.show()
files.download('🏆 Faturamento por Categoria de Produto.png')
plt.savefig('🏆 Faturamento por Categoria de Produto', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-4123505101.py:26: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- Estatísticas básicas ---
media_avaliacao = loja2['Avaliação da compra'].mean()
mediana_avaliacao = loja2['Avaliação da compra'].median()
moda_avaliacao = loja2['Avaliação da compra'].mode()[0]

print(f"Média das avaliações: {media_avaliacao:.2f}")
print(f"Mediana das avaliações: {mediana_avaliacao}")
print(f"Moda das avaliações: {moda_avaliacao}")

# --- Contagem de cada nota ---
contagem_notas = loja2['Avaliação da compra'].value_counts().sort_index()

# --- Exibir gráfico de barras ---
plt.figure(figsize=(8,5))
plt.bar(contagem_notas.index, contagem_notas.values, color='royalblue', edgecolor='black')
plt.title('Distribuição das Avaliações dos Clientes', fontsize=14, fontweight='bold')
plt.xlabel('Nota de Avaliação')
plt.ylabel('Quantidade de Clientes')
plt.xticks([1,2,3,4,5])
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# --- Percentual de avaliações positivas (>=4) ---
positivas = (loja2['Avaliação da compra'] >= 4).sum()
total = loja2['Avaliação da compra'].count()
percentual_positivas = (positivas / total) * 100

print(f"\n📈 Avaliações positivas (4 e 5): {percentual_positivas:.2f}% do total")
# Out:
# Média das avaliações: 4.04
# Mediana das avaliações: 5.0
# Moda das avaliações: 5
# 📈 Avaliações positivas (4 e 5): 75.63% do total

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files  # Para baixar o arquivo no Colab

# --- Filtrar avaliações positivas (nota >= 4) ---
avaliacoes_positivas = loja2[loja2['Avaliação da compra'] >= 4]

# --- Agrupar por produto: média e quantidade de avaliações ---
resumo_produtos = avaliacoes_positivas.groupby('Produto')['Avaliação da compra'].agg(['mean','count'])

# --- Selecionar TOP 5 produtos por média de avaliação ---
top5_produtos = resumo_produtos.sort_values('mean', ascending=False).head(5)

# --- Gráfico de bolhas ---
plt.figure(figsize=(10,6))
plt.scatter(
    x=top5_produtos.index,             # nomes dos produtos
    y=top5_produtos['mean'],           # média das avaliações
    s=top5_produtos['mean']*300,       # tamanho das bolhas proporcional à média
    color='mediumseagreen',
    alpha=0.7,
    edgecolors='black'
)

# Adicionar valores das médias acima das bolhas
for i, valor in enumerate(top5_produtos['mean']):
    plt.text(i, valor + 0.05, f"{valor:.2f}", ha='center', fontsize=10, fontweight='bold')

plt.title('🌟 TOP 5 Produtos Mais Bem Avaliados (nota ≥4)', fontsize=14, fontweight='bold')
plt.xlabel('Produto', fontsize=12)
plt.ylabel('Média das Avaliações', fontsize=12)
plt.ylim(4,5.2)  # Limite do eixo y para destacar notas altas
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# --- Salvar gráfico em .png ---
nome_arquivo = 'top5_produtos_bem_avaliados.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# --- Exibir gráfico ---
plt.show()

# --- Baixar gráfico automaticamente ---
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-599982922.py:34: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-599982922.py:38: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- Estatísticas básicas ---
media_avaliacao = loja3['Avaliação da compra'].mean()
mediana_avaliacao = loja3['Avaliação da compra'].median()
moda_avaliacao = loja3['Avaliação da compra'].mode()[0]

print(f"Média das avaliações: {media_avaliacao:.2f}")
print(f"Mediana das avaliações: {mediana_avaliacao}")
print(f"Moda das avaliações: {moda_avaliacao}")

# --- Contagem de cada nota ---
contagem_notas = loja3['Avaliação da compra'].value_counts().sort_index()

# --- Exibir gráfico de barras ---
plt.figure(figsize=(8,5))
plt.bar(contagem_notas.index, contagem_notas.values, color='royalblue', edgecolor='black')
plt.title('Distribuição das Avaliações dos Clientes', fontsize=14, fontweight='bold')
plt.xlabel('Nota de Avaliação')
plt.ylabel('Quantidade de Clientes')
plt.xticks([1,2,3,4,5])
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# --- Percentual de avaliações positivas (>=4) ---
positivas = (loja3['Avaliação da compra'] >= 4).sum()
total = loja3['Avaliação da compra'].count()
percentual_positivas = (positivas / total) * 100

print(f"\n📈 Avaliações positivas (4 e 5): {percentual_positivas:.2f}% do total")
# Out:
# Média das avaliações: 4.05
# Mediana das avaliações: 5.0
# Moda das avaliações: 5
# 📈 Avaliações positivas (4 e 5): 75.88% do total

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files  # Para baixar o arquivo no Colab

# --- Filtrar avaliações positivas (nota >= 4) ---
avaliacoes_positivas = loja3[loja3['Avaliação da compra'] >= 4]

# --- Agrupar por produto: média e quantidade de avaliações ---
resumo_produtos = avaliacoes_positivas.groupby('Produto')['Avaliação da compra'].agg(['mean','count'])

# --- Selecionar TOP 5 produtos por média de avaliação ---
top5_produtos = resumo_produtos.sort_values('mean', ascending=False).head(5)

# --- Gráfico de bolhas ---
plt.figure(figsize=(10,6))
plt.scatter(
    x=top5_produtos.index,             # nomes dos produtos
    y=top5_produtos['mean'],           # média das avaliações
    s=top5_produtos['mean']*300,       # tamanho das bolhas proporcional à média
    color='mediumseagreen',
    alpha=0.7,
    edgecolors='black'
)

# Adicionar valores das médias acima das bolhas
for i, valor in enumerate(top5_produtos['mean']):
    plt.text(i, valor + 0.05, f"{valor:.2f}", ha='center', fontsize=10, fontweight='bold')

plt.title('🌟 TOP 5 Produtos Mais Bem Avaliados (nota ≥4)', fontsize=14, fontweight='bold')
plt.xlabel('Produto', fontsize=12)
plt.ylabel('Média das Avaliações', fontsize=12)
plt.ylim(4,5.2)  # Limite do eixo y para destacar notas altas
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# --- Salvar gráfico em .png ---
nome_arquivo = 'top5_produtos_bem_avaliados.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# --- Exibir gráfico ---
plt.show()

# --- Baixar gráfico automaticamente ---
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-3971594188.py:34: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3971594188.py:38: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# Calcular o valor total vendido por produto
faturamento_produto = loja.groupby('Produto')['Preço'].sum().sort_values(ascending=True)

# Exibir os 10 produtos com menor faturamento
print("💸 Produtos com menor faturamento:")
print(faturamento_produto.head(10))
# Out:
# 💸 Produtos com menor faturamento:
# Produto
# Corda de pular                  870.89
# Dinossauro Rex                  918.40
# Cubo mágico 8x8                 929.27
# Jogo de copos                  1812.15
# Xadrez de madeira              1907.42
# Dashboards com Power BI        1940.86
# Blocos de montar               2487.74
# Boneca bebê                    2583.17
# Ciência de dados com python    2752.18
# Iniciando em programação       2791.03
# Name: Preço, dtype: float64

# %%
import matplotlib.pyplot as plt
from google.colab import files

# --- Contar os produtos menos vendidos ---
menos_vendidos = loja['Produto'].value_counts().sort_values(ascending=True).head(10)

# --- Criar o gráfico ---
plt.figure(figsize=(10,6))
barras = plt.barh(
    menos_vendidos.index,
    menos_vendidos.values,
    color='#87CEEB',       # azul suave
    edgecolor='black'
)

# --- Título e rótulos ---
plt.title('🔻 Top 10 Produtos Menos Vendidos', fontsize=16, fontweight='bold', pad=15)
plt.xlabel('Quantidade Vendida', fontsize=12)
plt.ylabel('Produto', fontsize=12)

# --- Adicionar rótulos de valor ao lado das barras ---
for barra, valor in zip(barras, menos_vendidos.values):
    plt.text(
        valor + 0.2,
        barra.get_y() + barra.get_height()/2,
        f'{valor}',
        va='center',
        fontsize=10,
        fontweight='bold'
    )

# --- Estilização ---
plt.gca().set_facecolor('#f8fafc')   # fundo suave
plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.box(False)
plt.tight_layout()

# --- Salvar o gráfico ---
nome_arquivo = 'menos_vendidos.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# --- Exibir ---
plt.show()

# --- Baixar automaticamente ---
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-3136872414.py:36: UserWarning: Glyph 128315 (\N{DOWN-POINTING RED TRIANGLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3136872414.py:40: UserWarning: Glyph 128315 (\N{DOWN-POINTING RED TRIANGLE}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128315 (\N{DOWN-POINTING RED TRIANGLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Calcular o valor total vendido por produto
faturamento_produto = loja2.groupby('Produto')['Preço'].sum().sort_values(ascending=True)

# Exibir os 10 produtos com menor faturamento
print("💸 Produtos com menor faturamento:")
print(faturamento_produto.head(10))
# Out:
# 💸 Produtos com menor faturamento:
# Produto
# Cubo mágico 8x8             858.22
# Dinossauro Rex             1027.41
# Corda de pular             1142.54
# Xadrez de madeira          1717.05
# Jogo de copos              2056.69
# Dashboards com Power BI    2132.93
# Faqueiro                   2310.25
# Blocos de montar           2385.91
# Bola de basquete           2788.23
# Copo térmico               2874.63
# Name: Preço, dtype: float64

# %%
import pandas as pd

url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"

loja2 = pd.read_csv(url2)

loja2 = loja2.dropna()

# Calcular o valor total vendido por produto
faturamento_produto = loja2.groupby('Produto')['Preço'].sum().sort_values(ascending=True)

# Exibir os 10 produtos com menor faturamento
print("💸 Produtos com menor faturamento:")
print(faturamento_produto.head(10))
# Out:
# 💸 Produtos com menor faturamento:
# Produto
# Cubo mágico 8x8             858.22
# Dinossauro Rex             1027.41
# Corda de pular             1142.54
# Xadrez de madeira          1717.05
# Jogo de copos              2056.69
# Dashboards com Power BI    2132.93
# Faqueiro                   2310.25
# Blocos de montar           2385.91
# Bola de basquete           2788.23
# Copo térmico               2874.63
# Name: Preço, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Agrupar por produto e somar vendas
ranking_produtos = loja3.groupby('Produto')['Preço'].sum().sort_values(ascending=False)

# Número de produtos principais que você quer destacar
top_n = 10

# Separar top N produtos e agrupar o restante em 'Outros'
top_produtos = ranking_produtos[:top_n]
outros_valor = ranking_produtos[top_n:].sum()

# Criar nova série incluindo 'Outros'
valores_pizza = pd.concat([top_produtos, pd.Series({'Outros': outros_valor})])


# Cores
cores = plt.cm.tab20.colors

# Explodir a fatia do produto que mais faturou
explode = [0.1] + [0]*(len(valores_pizza)-1)

# Criar gráfico de pizza
plt.figure(figsize=(9,9))
plt.pie(
    valores_pizza,
    labels=valores_pizza.index,
    autopct=lambda p: f"R$ {p * valores_pizza.sum() / 100:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."),
    colors=cores,
    startangle=90,
    wedgeprops={'edgecolor':'black'},
    explode=explode,
    shadow=True
)

plt.title(f'🏆 Top {top_n} Produtos Mais Vendidos + Outros (R$)', fontsize=14, fontweight='bold')
plt.axis('equal')  # Mantém a pizza redonda

# Salvar o gráfico
nome_arquivo = 'pizza_produtos_outros.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# Exibir gráfico
plt.show()

# Baixar gráfico
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-2729477377.py:43: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Calcular o valor total vendido por produto
faturamento_produto = loja3.groupby('Produto')['Preço'].sum().sort_values(ascending=True)

# Exibir os 10 produtos com menor faturamento
print("💸 Produtos com menor faturamento:")
print(faturamento_produto.head(10))
# Out:
# 💸 Produtos com menor faturamento:
# Produto
# Cubo mágico 8x8             853.81
# Dinossauro Rex             1060.78
# Corda de pular             1137.76
# Jogo de copos              1614.20
# Blocos de montar           1649.81
# Xadrez de madeira          1807.34
# Dashboards com Power BI    1829.81
# Copo térmico               2300.69
# Faqueiro                   2368.26
# Boneca bebê                2577.11
# Name: Preço, dtype: float64

# %%
import matplotlib.pyplot as plt
from google.colab import files

# --- Contar os produtos menos vendidos ---
menos_vendidos = loja3['Produto'].value_counts().sort_values(ascending=True).head(10)

# --- Criar o gráfico ---
plt.figure(figsize=(10,6))
barras = plt.barh(
    menos_vendidos.index,
    menos_vendidos.values,
    color='#87CEEB',       # azul suave
    edgecolor='black'
)

# --- Título e rótulos ---
plt.title('🔻 Top 10 Produtos Menos Vendidos', fontsize=16, fontweight='bold', pad=15)
plt.xlabel('Quantidade Vendida', fontsize=12)
plt.ylabel('Produto', fontsize=12)

# --- Adicionar rótulos de valor ao lado das barras ---
for barra, valor in zip(barras, menos_vendidos.values):
    plt.text(
        valor + 0.2,
        barra.get_y() + barra.get_height()/2,
        f'{valor}',
        va='center',
        fontsize=10,
        fontweight='bold'
    )

# --- Estilização ---
plt.gca().set_facecolor('#f8fafc')   # fundo suave
plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.box(False)
plt.tight_layout()

# --- Salvar o gráfico ---
nome_arquivo = 'menos_vendidos.png'
plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')

# --- Exibir ---
plt.show()

# --- Baixar automaticamente ---
files.download(nome_arquivo)
# Out:
# /tmp/ipython-input-1480804197.py:36: UserWarning: Glyph 128315 (\N{DOWN-POINTING RED TRIANGLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1480804197.py:40: UserWarning: Glyph 128315 (\N{DOWN-POINTING RED TRIANGLE}) missing from font(s) DejaVu Sans.
#   plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128315 (\N{DOWN-POINTING RED TRIANGLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ranking_categorias = loja4.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)
ranking_formatado = ranking_categorias.apply(lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Ranking de categorias (da mais vendida à menos vendida):")
print(ranking_formatado)
# Out:
# Ranking de categorias (da mais vendida à menos vendida):
# Categoria do Produto
# eletronicos              R$ 545.966,86
# eletrodomesticos         R$ 377.680,65
# moveis                   R$ 256.705,65
# instrumentos musicais    R$ 100.136,50
# esporte e lazer           R$ 44.465,65
# brinquedos                R$ 27.015,67
# utilidades domesticas     R$ 20.098,83
# livros                    R$ 12.427,77
# Name: Preço, dtype: object

# %%
import pandas as pd

url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja4 = pd.read_csv(url4)

loja4 = loja4.dropna()

ranking_categorias = loja4.groupby('Categoria do Produto')['Preço'].sum().sort_values(ascending=False)
ranking_formatado = ranking_categorias.apply(lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Ranking de categorias (da mais vendida à menos vendida):")
print(ranking_formatado)
# Out:
# Ranking de categorias (da mais vendida à menos vendida):
# Categoria do Produto
# eletronicos              R$ 545.966,86
# eletrodomesticos         R$ 377.680,65
# moveis                   R$ 256.705,65
# instrumentos musicais    R$ 100.136,50
# esporte e lazer           R$ 44.465,65
# brinquedos                R$ 27.015,67
# utilidades domesticas     R$ 20.098,83
# livros                    R$ 12.427,77
# Name: Preço, dtype: object

# %%
import pandas as pd

# Agrupar por produto e somar o valor total de vendas
ranking_produtos = loja4.groupby('Produto')['Preço'].sum().sort_values(ascending=False)

# Formatar os valores em reais
ranking_produtos_formatado = ranking_produtos.apply(
    lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
)

# Exibir o ranking formatado
print("🏆 Ranking dos produtos mais vendidos (em valor de R$):")
print(ranking_produtos_formatado.head(20))  # Mostra os 20 primeiros
# Out:
# 🏆 Ranking dos produtos mais vendidos (em valor de R$):
# Produto
# Celular Plus X42      R$ 128.930,07
# TV Led UHD 4K         R$ 120.393,25
# Smart TV              R$ 110.387,57
# Geladeira             R$ 100.362,59
# Tablet ABXY            R$ 75.630,75
# Lava louças            R$ 73.798,99
# Lavadora de roupas     R$ 69.951,68
# Secadora de roupas     R$ 56.349,30
# Celular ABXY           R$ 53.561,83
# Cama king              R$ 50.073,16
# Bateria                R$ 46.090,53
# Cama box               R$ 43.928,57
# Fogão                  R$ 43.094,36
# Sofá retrátil          R$ 42.787,68
# Guitarra               R$ 34.430,67
# Micro-ondas            R$ 34.123,73
# Bicicleta              R$ 28.572,45
# Guarda roupas          R$ 21.895,36
# Impressora             R$ 20.279,95
# Cômoda                 R$ 20.192,46
# Name: Preço, dtype: object

# %%
# Calcular o valor total vendido por produto
faturamento_produto = loja4.groupby('Produto')['Preço'].sum().sort_values(ascending=True)

# Exibir os 10 produtos com menor faturamento
print("💸 Produtos com menor faturamento:")
print(faturamento_produto.head(10))
# Out:
# 💸 Produtos com menor faturamento:
# Produto
# Corda de pular                  939.74
# Cubo mágico 8x8                 997.38
# Dinossauro Rex                 1143.94
# Xadrez de madeira              1434.09
# Jogo de copos                  1962.24
# Blocos de montar               2546.40
# Dashboards com Power BI        2654.28
# Ciência de dados com python    2811.87
# Iniciando em programação       2823.74
# Copo térmico                   2869.84
# Name: Preço, dtype: float64

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
import matplotlib.pyplot as plt

# Dados das lojas
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamento = [1534509.12, 1488459.06, 1464025.03, 1384497.58]
avaliacoes = [3.98, 4.04, 4.05, 4.00]
frete = [34.69, 33.62, 33.07, 31.28]

# Criação da figura e eixos
plt.figure(figsize=(10, 6))
barras = plt.bar(lojas, faturamento, color=['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728'], edgecolor='black')

# Adiciona os rótulos de valor acima das barras
for barra in barras:
    plt.text(barra.get_x() + barra.get_width() / 2,
             barra.get_height() + 10000,
             f'R$ {barra.get_height():,.0f}',
             ha='center', va='bottom', fontsize=10, fontweight='bold')

# Títulos e estilos
plt.title('💰 Faturamento Total por Loja', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Lojas', fontsize=12)
plt.ylabel('Faturamento (R$)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Exibe o gráfico
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'DejaVu Sans Pinyin' not found.
# ...

# %%
from google.colab import files
files.download('participacao_categorias_lojas.png')

# %%
## 📊 Faturamento Total
![Faturamento](imagens/faturamento_total.png)

## 🎯 Categorias por Loja
![Categorias](imagens/participacao_categorias.png)

## ⭐ Avaliações
![Avaliações](imagens/media_avaliacoes.png)

## 🚚 Frete Médio
![Frete](imagens/frete_medio.png)
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `imagens/faturamento_total.png'
# /bin/bash: -c: line 1: `[Faturamento](imagens/faturamento_total.png)'
# /bin/bash: -c: line 1: syntax error near unexpected token `imagens/participacao_categorias.png'
# /bin/bash: -c: line 1: `[Categorias](imagens/participacao_categorias.png)'
# /bin/bash: -c: line 1: syntax error near unexpected token `imagens/media_avaliacoes.png'
# /bin/bash: -c: line 1: `[Avaliações](imagens/media_avaliacoes.png)'
# /bin/bash: -c: line 1: syntax error near unexpected token `imagens/frete_medio.png'
# /bin/bash: -c: line 1: `[Frete](imagens/frete_medio.png)'

# %%
with open("README.md", "w", encoding="utf-8") as f:
    f.write("""
---

## 👨‍💻 Autor

**Guido Junior**
Estudante e entusiasta de análise de dados e ciência de dados.


💬 *“Cada gráfico conta uma história — e cada dado, uma oportunidade de aprender.”*

---

""")

# %%
conteudo_readme = """
# 🏪 Análise de Desempenho das Lojas – Projeto com Pandas

Este projeto analisa o desempenho de **quatro lojas diferentes** usando **Python (Pandas e Matplotlib)**.
Foram avaliados indicadores de **faturamento**, **frete**, **avaliação dos clientes** e **categorias de produtos**.

---

## 📊 Gráficos e Resultados

### 💰 Faturamento total por loja
![Faturamento Total](imagens/faturamento_total.png)

### 🎯 Faturamento por categoria
![Categorias](imagens/faturamento_por_categoria.png)

### ⭐ Média de avaliações dos clientes
![Avaliações](imagens/media_avaliacoes.png)

### 🚚 Frete médio por categoria
![Frete Médio](imagens/frete_medio.png)

---

## 📘 Tecnologias Utilizadas
- Python 3
- Google Colab
- Pandas
- Matplotlib

---

## 👨‍💻 Autor
**Guido Junior**
Estudante de análise de dados.

with open("README.md", "w", encoding="utf-8") as arquivo:
    arquivo.write(conteudo_readme)

print("✅ O arquivo README.md foi criado com sucesso!")
print("Você pode baixá-lo na barra lateral esquerda do Google Colab (ícone de pasta).")
# Out:
#   File "/tmp/ipython-input-1854963031.py", line 1
#     conteudo_readme = """
#                       ^
# SyntaxError: incomplete input

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("imagens", exist_ok=True)

dados_lojas = {
    "Loja 1": {
        "eletrônicos": 572659.23,
        "eletrodomésticos": 484913.36,
        "móveis": 250178.11,
        "instrumentos musicais": 121731.69,
        "esporte e lazer": 52387.55,
        "brinquedos": 23993.78,
        "utilidades domésticas": 16931.48,
        "livros": 11713.92
    },
    "Loja 2": {
        "eletrônicos": 547773.71,
        "eletrodomésticos": 464758.13,
        "móveis": 235234.68,
        "instrumentos musicais": 139987.03,
        "esporte e lazer": 46326.09,
        "brinquedos": 21262.21,
        "utilidades domésticas": 19662.86,
        "livros": 13454.35
    },
    "Loja 3": {
        "eletrônicos": 547699.92,
        "eletrodomésticos": 438984.89,
        "móveis": 268095.56,
        "instrumentos musicais": 103174.45,
        "esporte e lazer": 47456.10,
        "brinquedos": 25869.20,
        "utilidades domésticas": 20080.21,
        "livros": 12664.70
    },
    "Loja 4": {
        "eletrônicos": 545966.86,
        "eletrodomésticos": 377680.65,
        "móveis": 256705.65,
        "instrumentos musicais": 100136.50,
        "esporte e lazer": 44465.65,
        "brinquedos": 27015.67,
        "utilidades domésticas": 20098.83,
        "livros": 12427.77
    }
}

for loja, categorias in dados_lojas.items():
    plt.figure(figsize=(9, 5))
    categorias_ordenadas = dict(sorted(categorias.items(), key=lambda x: x[1], reverse=True))

    plt.plot(
        list(categorias_ordenadas.keys()),
        list(categorias_ordenadas.values()),
        marker='o',
        linewidth=2.5,
        color='royalblue'
    )

    plt.title(f"Faturamento por Categoria - {loja}", fontsize=14, weight='bold', pad=15)
    plt.xlabel("Categoria do Produto", fontsize=11)
    plt.ylabel("Faturamento (R$)", fontsize=11)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.xticks(rotation=25)
    plt.tight_layout()

    nome_arquivo = f"imagens/faturamento_por_categoria_{loja.lower().replace(' ', '_')}.png"

    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.close()

    print(f"✅ Gráfico salvo: {nome_arquivo}")

print("\n📁 Arquivos gerados na pasta 'imagens':")
print(os.listdir("imagens"))
